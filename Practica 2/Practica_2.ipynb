# %%
import numpy as np

# Función para calcular la distancia entre dos ciudades
def calcular_distancia(ciudad1, ciudad2):
    return np.linalg.norm(ciudad1 - ciudad2)

# Parámetros del algoritmo ACO
num_ciudades = 40 # Número de ciudades
num_hormigas = 100  # Número de hormigas
num_iteraciones = 500  # Número de iteraciones
alfa = 1.0  # Peso de la feromona
beta = 2.0  # Peso de la visibilidad
rho = 0.2  # Tasa de evaporación de la feromona
Q = 1.0  # Cantidad de feromona depositada por cada hormiga

# Crear una matriz de distancias aleatoria entre las ciudades
np.random.seed(0)
ciudades = np.random.rand(num_ciudades, 2)
distancias = np.zeros((num_ciudades, num_ciudades))
for i in range(num_ciudades):
    for j in range(num_ciudades):
        distancias[i, j] = calcular_distancia(ciudades[i], ciudades[j])

# Inicializar la matriz de feromona
feromonas = np.ones((num_ciudades, num_ciudades))

# Ciclo principal del algoritmo ACO
for iteracion in range(num_iteraciones):
    # Inicializar la lista de caminos de las hormigas
    caminos_hormigas = []
    costos_hormigas = []

    # Construir soluciones para cada hormiga
    for _ in range(num_hormigas):
        ciudad_actual = np.random.randint(num_ciudades)
        camino_hormiga = [ciudad_actual]
        costo_hormiga = 0

        # Construir el camino de la hormiga
        for _ in range(num_ciudades - 1):
            # Calcular la probabilidad de moverse a cada ciudad vecina
            probabilidad_transicion = (
                (feromonas[ciudad_actual] ** alfa) * (1 / (distancias[ciudad_actual] + 1e-10) ** beta)
            )
            probabilidad_transicion[probabilidad_transicion == np.inf] = 0  # Reemplazar inf por 0
            probabilidad_transicion /= probabilidad_transicion.sum()

            # Elegir la próxima ciudad basada en la probabilidad
            siguiente_ciudad = np.random.choice(np.arange(num_ciudades), p=probabilidad_transicion)
            camino_hormiga.append(siguiente_ciudad)
            costo_hormiga += distancias[ciudad_actual, siguiente_ciudad]
            ciudad_actual = siguiente_ciudad

        # Agregar el costo del regreso al punto de partida
        costo_hormiga += distancias[camino_hormiga[-1], camino_hormiga[0]]

        caminos_hormigas.append(camino_hormiga)
        costos_hormigas.append(costo_hormiga)

    # Actualizar la feromona en los caminos de las hormigas
    feromonas *= (1 - rho)  # Evaporación
    for i in range(num_hormigas):
        for j in range(num_ciudades - 1):
            ciudad_actual = caminos_hormigas[i][j]
            siguiente_ciudad = caminos_hormigas[i][j + 1]
            feromonas[ciudad_actual, siguiente_ciudad] += (Q / costos_hormigas[i])

    # Encontrar el mejor camino de esta iteración
    mejor_camino = caminos_hormigas[np.argmin(costos_hormigas)]
    mejor_costo = min(costos_hormigas)

    print(f"Iteración {iteracion + 1}: Mejor costo = {mejor_costo}")

# Resultado final
print("Mejor camino encontrado:")
print(mejor_camino)
print("Mejor costo encontrado:", mejor_costo)
# Out:
# <ipython-input-20-53cf7817f099>:66: RuntimeWarning: divide by zero encountered in double_scalars
#   feromonas[ciudad_actual, siguiente_ciudad] += (Q / costos_hormigas[i])
# Iteración 1: Mejor costo = 0.0
# Iteración 2: Mejor costo = 0.0
# Iteración 3: Mejor costo = 0.0
# Iteración 4: Mejor costo = 0.5365559082888296
# Iteración 5: Mejor costo = 0.5365559082888296
# Iteración 6: Mejor costo = 0.5365559082888296
# Iteración 7: Mejor costo = 0.5365559082888296
# Iteración 8: Mejor costo = 0.5365559082888296
# Iteración 9: Mejor costo = 0.5365559082888296
# Iteración 10: Mejor costo = 0.5365559082888296
# Iteración 11: Mejor costo = 0.5365559082888296
# Iteración 12: Mejor costo = 0.5365559082888296
# Iteración 13: Mejor costo = 0.5365559082888296
# Iteración 14: Mejor costo = 0.5365559082888296
# Iteración 15: Mejor costo = 0.5365559082888296
# Iteración 16: Mejor costo = 0.5365559082888296
# Iteración 17: Mejor costo = 0.5365559082888296
# Iteración 18: Mejor costo = 0.5365559082888296
# Iteración 19: Mejor costo = 0.5365559082888296
# Iteración 20: Mejor costo = 0.5365559082888296
# Iteración 21: Mejor costo = 0.5365559082888296
# Iteración 22: Mejor costo = 0.5365559082888296
# Iteración 23: Mejor costo = 0.5365559082888296
# Iteración 24: Mejor costo = 0.5365559082888296
# Iteración 25: Mejor costo = 0.5365559082888296
# Iteración 26: Mejor costo = 0.5365559082888296
# Iteración 27: Mejor costo = 0.5365559082888296
# Iteración 28: Mejor costo = 0.5365559082888296
# Iteración 29: Mejor costo = 0.5365559082888296
# Iteración 30: Mejor costo = 0.5365559082888296
# Iteración 31: Mejor costo = 0.5365559082888296
# Iteración 32: Mejor costo = 0.5365559082888296
# Iteración 33: Mejor costo = 0.5365559082888296
# Iteración 34: Mejor costo = 0.5365559082888296
# Iteración 35: Mejor costo = 0.5365559082888296
# Iteración 36: Mejor costo = 0.5365559082888296
# Iteración 37: Mejor costo = 0.5365559082888296
# Iteración 38: Mejor costo = 0.5365559082888296
# Iteración 39: Mejor costo = 0.5365559082888296
# Iteración 40: Mejor costo = 0.5365559082888296
# Iteración 41: Mejor costo = 0.5365559082888296
# Iteración 42: Mejor costo = 0.5365559082888296
# Iteración 43: Mejor costo = 0.5365559082888296
# Iteración 44: Mejor costo = 0.5365559082888296
# Iteración 45: Mejor costo = 0.5365559082888296
# Iteración 46: Mejor costo = 0.5365559082888296
# Iteración 47: Mejor costo = 0.5365559082888296
# Iteración 48: Mejor costo = 0.5365559082888296
# Iteración 49: Mejor costo = 0.5365559082888296
# Iteración 50: Mejor costo = 0.5365559082888296
# Iteración 51: Mejor costo = 0.5365559082888296
# Iteración 52: Mejor costo = 0.5365559082888296
# Iteración 53: Mejor costo = 0.5365559082888296
# Iteración 54: Mejor costo = 0.5365559082888296
# Iteración 55: Mejor costo = 0.5365559082888296
# Iteración 56: Mejor costo = 0.5365559082888296
# Iteración 57: Mejor costo = 0.5365559082888296
# Iteración 58: Mejor costo = 0.5365559082888296
# Iteración 59: Mejor costo = 0.5365559082888296
# Iteración 60: Mejor costo = 0.5365559082888296
# Iteración 61: Mejor costo = 0.5365559082888296
# Iteración 62: Mejor costo = 0.5365559082888296
# Iteración 63: Mejor costo = 0.5365559082888296
# Iteración 64: Mejor costo = 0.5365559082888296
# Iteración 65: Mejor costo = 0.5365559082888296
# Iteración 66: Mejor costo = 0.5365559082888296
# Iteración 67: Mejor costo = 0.5365559082888296
# Iteración 68: Mejor costo = 0.5365559082888296
# Iteración 69: Mejor costo = 0.5365559082888296
# Iteración 70: Mejor costo = 0.5365559082888296
# Iteración 71: Mejor costo = 0.5365559082888296
# Iteración 72: Mejor costo = 0.5365559082888296
# Iteración 73: Mejor costo = 0.5365559082888296
# Iteración 74: Mejor costo = 0.5365559082888296
# Iteración 75: Mejor costo = 0.5365559082888296
# Iteración 76: Mejor costo = 0.5365559082888296
# Iteración 77: Mejor costo = 0.5365559082888296
# Iteración 78: Mejor costo = 0.5365559082888296
# Iteración 79: Mejor costo = 0.5365559082888296
# Iteración 80: Mejor costo = 0.5365559082888296
# Iteración 81: Mejor costo = 0.5365559082888296
# Iteración 82: Mejor costo = 0.5365559082888296
# Iteración 83: Mejor costo = 0.5365559082888296
# Iteración 84: Mejor costo = 0.5365559082888296
# Iteración 85: Mejor costo = 0.5365559082888296
# Iteración 86: Mejor costo = 0.5365559082888296
# Iteración 87: Mejor costo = 0.5365559082888296
# Iteración 88: Mejor costo = 0.5365559082888296
# Iteración 89: Mejor costo = 0.5365559082888296
# Iteración 90: Mejor costo = 0.5365559082888296
# Iteración 91: Mejor costo = 0.5365559082888296
# Iteración 92: Mejor costo = 0.5365559082888296
# Iteración 93: Mejor costo = 0.5365559082888296
# Iteración 94: Mejor costo = 0.5365559082888296
# Iteración 95: Mejor costo = 0.5365559082888296
# Iteración 96: Mejor costo = 0.5365559082888296
# Iteración 97: Mejor costo = 0.5365559082888296
# Iteración 98: Mejor costo = 0.5365559082888296
# Iteración 99: Mejor costo = 0.5365559082888296
# Iteración 100: Mejor costo = 0.5365559082888296
# Iteración 101: Mejor costo = 0.5365559082888296
# Iteración 102: Mejor costo = 0.5365559082888296
# Iteración 103: Mejor costo = 0.5365559082888296
# Iteración 104: Mejor costo = 0.5365559082888296
# Iteración 105: Mejor costo = 0.5365559082888296
# Iteración 106: Mejor costo = 0.5365559082888296
# Iteración 107: Mejor costo = 0.5365559082888296
# Iteración 108: Mejor costo = 0.5365559082888296
# Iteración 109: Mejor costo = 0.5365559082888296
# Iteración 110: Mejor costo = 0.5365559082888296
# Iteración 111: Mejor costo = 0.5365559082888296
# Iteración 112: Mejor costo = 0.5365559082888296
# Iteración 113: Mejor costo = 0.5365559082888296
# Iteración 114: Mejor costo = 0.5365559082888296
# Iteración 115: Mejor costo = 0.5365559082888296
# Iteración 116: Mejor costo = 0.5365559082888296
# Iteración 117: Mejor costo = 0.5365559082888296
# Iteración 118: Mejor costo = 0.5365559082888296
# Iteración 119: Mejor costo = 0.5365559082888296
# Iteración 120: Mejor costo = 0.5365559082888296
# Iteración 121: Mejor costo = 0.5365559082888296
# Iteración 122: Mejor costo = 0.5365559082888296
# Iteración 123: Mejor costo = 0.5365559082888296
# Iteración 124: Mejor costo = 0.5365559082888296
# Iteración 125: Mejor costo = 0.5365559082888296
# Iteración 126: Mejor costo = 0.5365559082888296
# Iteración 127: Mejor costo = 0.5365559082888296
# Iteración 128: Mejor costo = 0.5365559082888296
# Iteración 129: Mejor costo = 0.5365559082888296
# Iteración 130: Mejor costo = 0.5365559082888296
# Iteración 131: Mejor costo = 0.5365559082888296
# Iteración 132: Mejor costo = 0.5365559082888296
# Iteración 133: Mejor costo = 0.5365559082888296
# Iteración 134: Mejor costo = 0.5365559082888296
# Iteración 135: Mejor costo = 0.5365559082888296
# Iteración 136: Mejor costo = 0.5365559082888296
# Iteración 137: Mejor costo = 0.5365559082888296
# Iteración 138: Mejor costo = 0.5365559082888296
# Iteración 139: Mejor costo = 0.5365559082888296
# Iteración 140: Mejor costo = 0.5365559082888296
# Iteración 141: Mejor costo = 0.5365559082888296
# Iteración 142: Mejor costo = 0.5365559082888296
# Iteración 143: Mejor costo = 0.5365559082888296
# Iteración 144: Mejor costo = 0.5365559082888296
# Iteración 145: Mejor costo = 0.5365559082888296
# Iteración 146: Mejor costo = 0.5365559082888296
# Iteración 147: Mejor costo = 0.5365559082888296
# Iteración 148: Mejor costo = 0.5365559082888296
# Iteración 149: Mejor costo = 0.5365559082888296
# Iteración 150: Mejor costo = 0.5365559082888296
# Iteración 151: Mejor costo = 0.5365559082888296
# Iteración 152: Mejor costo = 0.5365559082888296
# Iteración 153: Mejor costo = 0.5365559082888296
# Iteración 154: Mejor costo = 0.5365559082888296
# Iteración 155: Mejor costo = 0.5365559082888296
# Iteración 156: Mejor costo = 0.5365559082888296
# Iteración 157: Mejor costo = 0.5365559082888296
# Iteración 158: Mejor costo = 0.5365559082888296
# Iteración 159: Mejor costo = 0.5365559082888296
# Iteración 160: Mejor costo = 0.5365559082888296
# Iteración 161: Mejor costo = 0.5365559082888296
# Iteración 162: Mejor costo = 0.5365559082888296
# Iteración 163: Mejor costo = 0.5365559082888296
# Iteración 164: Mejor costo = 0.5365559082888296
# Iteración 165: Mejor costo = 0.5365559082888296
# Iteración 166: Mejor costo = 0.5365559082888296
# Iteración 167: Mejor costo = 0.5365559082888296
# Iteración 168: Mejor costo = 0.5365559082888296
# Iteración 169: Mejor costo = 0.5365559082888296
# Iteración 170: Mejor costo = 0.5365559082888296
# Iteración 171: Mejor costo = 0.5365559082888296
# Iteración 172: Mejor costo = 0.5365559082888296
# Iteración 173: Mejor costo = 0.5365559082888296
# Iteración 174: Mejor costo = 0.5365559082888296
# Iteración 175: Mejor costo = 0.5365559082888296
# Iteración 176: Mejor costo = 0.5365559082888296
# Iteración 177: Mejor costo = 0.5365559082888296
# Iteración 178: Mejor costo = 0.5365559082888296
# Iteración 179: Mejor costo = 0.5365559082888296
# Iteración 180: Mejor costo = 0.5365559082888296
# Iteración 181: Mejor costo = 0.5365559082888296
# Iteración 182: Mejor costo = 0.5365559082888296
# Iteración 183: Mejor costo = 0.5365559082888296
# Iteración 184: Mejor costo = 0.5365559082888296
# Iteración 185: Mejor costo = 0.5365559082888296
# Iteración 186: Mejor costo = 0.5365559082888296
# Iteración 187: Mejor costo = 0.5365559082888296
# Iteración 188: Mejor costo = 0.5365559082888296
# Iteración 189: Mejor costo = 0.5365559082888296
# Iteración 190: Mejor costo = 0.5365559082888296
# Iteración 191: Mejor costo = 0.5365559082888296
# Iteración 192: Mejor costo = 0.5365559082888296
# Iteración 193: Mejor costo = 0.5365559082888296
# Iteración 194: Mejor costo = 0.5365559082888296
# Iteración 195: Mejor costo = 0.5365559082888296
# Iteración 196: Mejor costo = 0.5365559082888296
# Iteración 197: Mejor costo = 0.5365559082888296
# Iteración 198: Mejor costo = 0.5365559082888296
# Iteración 199: Mejor costo = 0.5365559082888296
# Iteración 200: Mejor costo = 0.5365559082888296
# Iteración 201: Mejor costo = 0.5365559082888296
# Iteración 202: Mejor costo = 0.5365559082888296
# Iteración 203: Mejor costo = 0.5365559082888296
# Iteración 204: Mejor costo = 0.5365559082888296
# Iteración 205: Mejor costo = 0.5365559082888296
# Iteración 206: Mejor costo = 0.5365559082888296
# Iteración 207: Mejor costo = 0.5365559082888296
# Iteración 208: Mejor costo = 0.5365559082888296
# Iteración 209: Mejor costo = 0.5365559082888296
# Iteración 210: Mejor costo = 0.5365559082888296
# Iteración 211: Mejor costo = 0.5365559082888296
# Iteración 212: Mejor costo = 0.5365559082888296
# Iteración 213: Mejor costo = 0.5365559082888296
# Iteración 214: Mejor costo = 0.5365559082888296
# Iteración 215: Mejor costo = 0.5365559082888296
# Iteración 216: Mejor costo = 0.5365559082888296
# Iteración 217: Mejor costo = 0.5365559082888296
# Iteración 218: Mejor costo = 0.5365559082888296
# Iteración 219: Mejor costo = 0.5365559082888296
# Iteración 220: Mejor costo = 0.5365559082888296
# Iteración 221: Mejor costo = 0.5365559082888296
# Iteración 222: Mejor costo = 0.5365559082888296
# Iteración 223: Mejor costo = 0.5365559082888296
# Iteración 224: Mejor costo = 0.5365559082888296
# Iteración 225: Mejor costo = 0.5365559082888296
# Iteración 226: Mejor costo = 0.5365559082888296
# Iteración 227: Mejor costo = 0.5365559082888296
# Iteración 228: Mejor costo = 0.5365559082888296
# Iteración 229: Mejor costo = 0.5365559082888296
# Iteración 230: Mejor costo = 0.5365559082888296
# Iteración 231: Mejor costo = 0.5365559082888296
# Iteración 232: Mejor costo = 0.5365559082888296
# Iteración 233: Mejor costo = 0.5365559082888296
# Iteración 234: Mejor costo = 0.5365559082888296
# Iteración 235: Mejor costo = 0.5365559082888296
# Iteración 236: Mejor costo = 0.5365559082888296
# Iteración 237: Mejor costo = 0.5365559082888296
# Iteración 238: Mejor costo = 0.5365559082888296
# Iteración 239: Mejor costo = 0.5365559082888296
# Iteración 240: Mejor costo = 0.5365559082888296
# Iteración 241: Mejor costo = 0.5365559082888296
# Iteración 242: Mejor costo = 0.5365559082888296
# Iteración 243: Mejor costo = 0.5365559082888296
# Iteración 244: Mejor costo = 0.5365559082888296
# Iteración 245: Mejor costo = 0.5365559082888296
# Iteración 246: Mejor costo = 0.5365559082888296
# Iteración 247: Mejor costo = 0.5365559082888296
# Iteración 248: Mejor costo = 0.5365559082888296
# Iteración 249: Mejor costo = 0.5365559082888296
# Iteración 250: Mejor costo = 0.5365559082888296
# Iteración 251: Mejor costo = 0.5365559082888296
# Iteración 252: Mejor costo = 0.5365559082888296
# Iteración 253: Mejor costo = 0.5365559082888296
# Iteración 254: Mejor costo = 0.5365559082888296
# Iteración 255: Mejor costo = 0.5365559082888296
# Iteración 256: Mejor costo = 0.5365559082888296
# Iteración 257: Mejor costo = 0.5365559082888296
# Iteración 258: Mejor costo = 0.5365559082888296
# Iteración 259: Mejor costo = 0.5365559082888296
# Iteración 260: Mejor costo = 0.5365559082888296
# Iteración 261: Mejor costo = 0.5365559082888296
# Iteración 262: Mejor costo = 0.5365559082888296
# Iteración 263: Mejor costo = 0.5365559082888296
# Iteración 264: Mejor costo = 0.5365559082888296
# Iteración 265: Mejor costo = 0.5365559082888296
# Iteración 266: Mejor costo = 0.5365559082888296
# Iteración 267: Mejor costo = 0.5365559082888296
# Iteración 268: Mejor costo = 0.5365559082888296
# Iteración 269: Mejor costo = 0.5365559082888296
# Iteración 270: Mejor costo = 0.5365559082888296
# Iteración 271: Mejor costo = 0.5365559082888296
# Iteración 272: Mejor costo = 0.5365559082888296
# Iteración 273: Mejor costo = 0.5365559082888296
# Iteración 274: Mejor costo = 0.5365559082888296
# Iteración 275: Mejor costo = 0.5365559082888296
# Iteración 276: Mejor costo = 0.5365559082888296
# Iteración 277: Mejor costo = 0.5365559082888296
# Iteración 278: Mejor costo = 0.5365559082888296
# Iteración 279: Mejor costo = 0.5365559082888296
# Iteración 280: Mejor costo = 0.5365559082888296
# Iteración 281: Mejor costo = 0.5365559082888296
# Iteración 282: Mejor costo = 0.5365559082888296
# Iteración 283: Mejor costo = 0.5365559082888296
# Iteración 284: Mejor costo = 0.5365559082888296
# Iteración 285: Mejor costo = 0.5365559082888296
# Iteración 286: Mejor costo = 0.5365559082888296
# Iteración 287: Mejor costo = 0.5365559082888296
# Iteración 288: Mejor costo = 0.5365559082888296
# Iteración 289: Mejor costo = 0.5365559082888296
# Iteración 290: Mejor costo = 0.5365559082888296
# Iteración 291: Mejor costo = 0.5365559082888296
# Iteración 292: Mejor costo = 0.5365559082888296
# Iteración 293: Mejor costo = 0.5365559082888296
# Iteración 294: Mejor costo = 0.5365559082888296
# Iteración 295: Mejor costo = 0.5365559082888296
# Iteración 296: Mejor costo = 0.5365559082888296
# Iteración 297: Mejor costo = 0.5365559082888296
# Iteración 298: Mejor costo = 0.5365559082888296
# Iteración 299: Mejor costo = 0.5365559082888296
# Iteración 300: Mejor costo = 0.5365559082888296
# Iteración 301: Mejor costo = 0.5365559082888296
# Iteración 302: Mejor costo = 0.5365559082888296
# Iteración 303: Mejor costo = 0.5365559082888296
# Iteración 304: Mejor costo = 0.5365559082888296
# Iteración 305: Mejor costo = 0.5365559082888296
# Iteración 306: Mejor costo = 0.5365559082888296
# Iteración 307: Mejor costo = 0.5365559082888296
# Iteración 308: Mejor costo = 0.5365559082888296
# Iteración 309: Mejor costo = 0.5365559082888296
# Iteración 310: Mejor costo = 0.5365559082888296
# Iteración 311: Mejor costo = 0.5365559082888296
# Iteración 312: Mejor costo = 0.5365559082888296
# Iteración 313: Mejor costo = 0.5365559082888296
# Iteración 314: Mejor costo = 0.5365559082888296
# Iteración 315: Mejor costo = 0.5365559082888296
# Iteración 316: Mejor costo = 0.5365559082888296
# Iteración 317: Mejor costo = 0.5365559082888296
# Iteración 318: Mejor costo = 0.5365559082888296
# Iteración 319: Mejor costo = 0.5365559082888296
# Iteración 320: Mejor costo = 0.5365559082888296
# Iteración 321: Mejor costo = 0.5365559082888296
# Iteración 322: Mejor costo = 0.5365559082888296
# Iteración 323: Mejor costo = 0.5365559082888296
# Iteración 324: Mejor costo = 0.5365559082888296
# Iteración 325: Mejor costo = 0.5365559082888296
# Iteración 326: Mejor costo = 0.5365559082888296
# Iteración 327: Mejor costo = 0.5365559082888296
# Iteración 328: Mejor costo = 0.5365559082888296
# Iteración 329: Mejor costo = 0.5365559082888296
# Iteración 330: Mejor costo = 0.5365559082888296
# Iteración 331: Mejor costo = 0.5365559082888296
# Iteración 332: Mejor costo = 0.5365559082888296
# Iteración 333: Mejor costo = 0.5365559082888296
# Iteración 334: Mejor costo = 0.5365559082888296
# Iteración 335: Mejor costo = 0.5365559082888296
# Iteración 336: Mejor costo = 0.5365559082888296
# Iteración 337: Mejor costo = 0.5365559082888296
# Iteración 338: Mejor costo = 0.5365559082888296
# Iteración 339: Mejor costo = 0.5365559082888296
# Iteración 340: Mejor costo = 0.6792526707516218
# Iteración 341: Mejor costo = 0.5365559082888296
# Iteración 342: Mejor costo = 0.5365559082888296
# Iteración 343: Mejor costo = 0.5365559082888296
# Iteración 344: Mejor costo = 0.5365559082888296
# Iteración 345: Mejor costo = 0.5365559082888296
# Iteración 346: Mejor costo = 0.5365559082888296
# Iteración 347: Mejor costo = 0.5365559082888296
# Iteración 348: Mejor costo = 0.5365559082888296
# Iteración 349: Mejor costo = 0.5365559082888296
# Iteración 350: Mejor costo = 0.5365559082888296
# Iteración 351: Mejor costo = 0.5365559082888296
# Iteración 352: Mejor costo = 0.5365559082888296
# Iteración 353: Mejor costo = 0.5365559082888296
# Iteración 354: Mejor costo = 0.5365559082888296
# Iteración 355: Mejor costo = 0.5365559082888296
# Iteración 356: Mejor costo = 0.5365559082888296
# Iteración 357: Mejor costo = 0.5365559082888296
# Iteración 358: Mejor costo = 0.5365559082888296
# Iteración 359: Mejor costo = 0.5365559082888296
# Iteración 360: Mejor costo = 0.5365559082888296
# Iteración 361: Mejor costo = 0.5365559082888296
# Iteración 362: Mejor costo = 0.5365559082888296
# Iteración 363: Mejor costo = 0.5365559082888296
# Iteración 364: Mejor costo = 0.5365559082888296
# Iteración 365: Mejor costo = 0.5365559082888296
# Iteración 366: Mejor costo = 0.5365559082888296
# Iteración 367: Mejor costo = 0.5365559082888296
# Iteración 368: Mejor costo = 0.5365559082888296
# Iteración 369: Mejor costo = 0.5365559082888296
# Iteración 370: Mejor costo = 0.5365559082888296
# Iteración 371: Mejor costo = 0.5365559082888296
# Iteración 372: Mejor costo = 0.5365559082888296
# Iteración 373: Mejor costo = 0.5365559082888296
# Iteración 374: Mejor costo = 0.5365559082888296
# Iteración 375: Mejor costo = 0.5365559082888296
# Iteración 376: Mejor costo = 0.5365559082888296
# Iteración 377: Mejor costo = 0.5365559082888296
# Iteración 378: Mejor costo = 0.5365559082888296
# Iteración 379: Mejor costo = 0.5365559082888296
# Iteración 380: Mejor costo = 0.5365559082888296
# Iteración 381: Mejor costo = 0.5365559082888296
# Iteración 382: Mejor costo = 0.5365559082888296
# Iteración 383: Mejor costo = 0.5365559082888296
# Iteración 384: Mejor costo = 0.5365559082888296
# Iteración 385: Mejor costo = 0.5365559082888296
# Iteración 386: Mejor costo = 0.5365559082888296
# Iteración 387: Mejor costo = 0.5365559082888296
# Iteración 388: Mejor costo = 0.5365559082888296
# Iteración 389: Mejor costo = 0.5365559082888296
# Iteración 390: Mejor costo = 0.5365559082888296
# Iteración 391: Mejor costo = 0.5365559082888296
# Iteración 392: Mejor costo = 0.5365559082888296
# Iteración 393: Mejor costo = 0.5365559082888296
# Iteración 394: Mejor costo = 0.5365559082888296
# Iteración 395: Mejor costo = 0.5365559082888296
# Iteración 396: Mejor costo = 0.5365559082888296
# Iteración 397: Mejor costo = 0.5365559082888296
# Iteración 398: Mejor costo = 0.5365559082888296
# Iteración 399: Mejor costo = 0.5365559082888296
# Iteración 400: Mejor costo = 0.5365559082888296
# Iteración 401: Mejor costo = 0.6792526707516218
# Iteración 402: Mejor costo = 0.5365559082888296
# Iteración 403: Mejor costo = 0.5365559082888296
# Iteración 404: Mejor costo = 0.5365559082888296
# Iteración 405: Mejor costo = 0.5365559082888296
# Iteración 406: Mejor costo = 0.5365559082888296
# Iteración 407: Mejor costo = 0.5365559082888296
# Iteración 408: Mejor costo = 0.5365559082888296
# Iteración 409: Mejor costo = 0.5365559082888296
# Iteración 410: Mejor costo = 0.5365559082888296
# Iteración 411: Mejor costo = 0.5365559082888296
# Iteración 412: Mejor costo = 0.5365559082888296
# Iteración 413: Mejor costo = 0.5365559082888296
# Iteración 414: Mejor costo = 0.5365559082888296
# Iteración 415: Mejor costo = 0.5365559082888296
# Iteración 416: Mejor costo = 0.5365559082888296
# Iteración 417: Mejor costo = 0.5365559082888296
# Iteración 418: Mejor costo = 0.5365559082888296
# Iteración 419: Mejor costo = 0.5365559082888296
# Iteración 420: Mejor costo = 0.5365559082888296
# Iteración 421: Mejor costo = 0.5365559082888296
# Iteración 422: Mejor costo = 0.5365559082888296
# Iteración 423: Mejor costo = 0.5365559082888296
# Iteración 424: Mejor costo = 0.5365559082888296
# Iteración 425: Mejor costo = 0.5365559082888296
# Iteración 426: Mejor costo = 0.5365559082888296
# Iteración 427: Mejor costo = 0.5365559082888296
# Iteración 428: Mejor costo = 0.5365559082888296
# Iteración 429: Mejor costo = 0.5365559082888296
# Iteración 430: Mejor costo = 0.5365559082888296
# Iteración 431: Mejor costo = 0.5365559082888296
# Iteración 432: Mejor costo = 0.5365559082888296
# Iteración 433: Mejor costo = 0.5365559082888296
# Iteración 434: Mejor costo = 0.5365559082888296
# Iteración 435: Mejor costo = 0.5365559082888296
# Iteración 436: Mejor costo = 0.5365559082888296
# Iteración 437: Mejor costo = 0.5365559082888296
# Iteración 438: Mejor costo = 0.5365559082888296
# Iteración 439: Mejor costo = 0.5365559082888296
# Iteración 440: Mejor costo = 0.5365559082888296
# Iteración 441: Mejor costo = 0.5365559082888296
# Iteración 442: Mejor costo = 0.5365559082888296
# Iteración 443: Mejor costo = 0.5365559082888296
# Iteración 444: Mejor costo = 0.5365559082888296
# Iteración 445: Mejor costo = 0.5365559082888296
# Iteración 446: Mejor costo = 0.5365559082888296
# Iteración 447: Mejor costo = 0.5365559082888296
# Iteración 448: Mejor costo = 0.5365559082888296
# Iteración 449: Mejor costo = 0.5365559082888296
# Iteración 450: Mejor costo = 0.5365559082888296
# Iteración 451: Mejor costo = 0.5365559082888296
# Iteración 452: Mejor costo = 0.5365559082888296
# Iteración 453: Mejor costo = 0.5365559082888296
# Iteración 454: Mejor costo = 0.5365559082888296
# Iteración 455: Mejor costo = 0.5365559082888296
# Iteración 456: Mejor costo = 0.5365559082888296
# Iteración 457: Mejor costo = 0.5365559082888296
# Iteración 458: Mejor costo = 0.5365559082888296
# Iteración 459: Mejor costo = 0.5365559082888296
# Iteración 460: Mejor costo = 0.5365559082888296
# Iteración 461: Mejor costo = 0.5365559082888296
# Iteración 462: Mejor costo = 0.5365559082888296
# Iteración 463: Mejor costo = 0.5365559082888296
# Iteración 464: Mejor costo = 0.5365559082888296
# Iteración 465: Mejor costo = 0.5365559082888296
# Iteración 466: Mejor costo = 0.5365559082888296
# Iteración 467: Mejor costo = 0.5365559082888296
# Iteración 468: Mejor costo = 0.5365559082888296
# Iteración 469: Mejor costo = 0.5365559082888296
# Iteración 470: Mejor costo = 0.5365559082888296
# Iteración 471: Mejor costo = 0.5365559082888296
# Iteración 472: Mejor costo = 0.5365559082888296
# Iteración 473: Mejor costo = 0.5365559082888296
# Iteración 474: Mejor costo = 0.5365559082888296
# Iteración 475: Mejor costo = 0.5365559082888296
# Iteración 476: Mejor costo = 0.5365559082888296
# Iteración 477: Mejor costo = 0.5365559082888296
# Iteración 478: Mejor costo = 0.5365559082888296
# Iteración 479: Mejor costo = 0.5365559082888296
# Iteración 480: Mejor costo = 0.5365559082888296
# Iteración 481: Mejor costo = 0.5365559082888296
# Iteración 482: Mejor costo = 0.5365559082888296
# Iteración 483: Mejor costo = 0.5365559082888296
# Iteración 484: Mejor costo = 0.5365559082888296
# Iteración 485: Mejor costo = 0.5365559082888296
# Iteración 486: Mejor costo = 0.5365559082888296
# Iteración 487: Mejor costo = 0.5365559082888296
# Iteración 488: Mejor costo = 0.5365559082888296
# Iteración 489: Mejor costo = 0.5365559082888296
# Iteración 490: Mejor costo = 0.5365559082888296
# Iteración 491: Mejor costo = 0.5365559082888296
# Iteración 492: Mejor costo = 0.6792526707516218
# Iteración 493: Mejor costo = 0.5365559082888296
# Iteración 494: Mejor costo = 0.5365559082888296
# Iteración 495: Mejor costo = 0.5365559082888296
# Iteración 496: Mejor costo = 0.5365559082888296
# Iteración 497: Mejor costo = 0.5365559082888296
# Iteración 498: Mejor costo = 0.5365559082888296
# Iteración 499: Mejor costo = 0.5365559082888296
# Iteración 500: Mejor costo = 0.5365559082888296
# Mejor camino encontrado:
# [38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39, 38, 39]
# Mejor costo encontrado: 0.5365559082888296
